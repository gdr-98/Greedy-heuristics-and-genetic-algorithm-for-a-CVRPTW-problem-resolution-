# %% [markdown]
# # Capacitated Vehicle Routing with Time Window

# %% [markdown]
# ## Inizializzazione

# %% [markdown]
# ### Librerie

# %%
import gurobipy as gb
from gurobipy import *
import re
import random
import matplotlib.pyplot as plt
import networkx as nx

import matplotlib.pyplot as plt
'''
def distance(city1, city2):
    i = coordinate[city1]
    j = coordinate[city2]
    diff = (i[0]-j[0], i[1]-j[1])
    return math.sqrt(diff[0]*diff[0]+diff[1]*diff[1])
'''
   

plt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# ### Classi

# %%
class Node:
    def __init__(self, number, coordinate, demand, rdy_time, due_date, serv_time):
        self.number = number
        self.coordinate = coordinate
        self.demand = demand
        self.rdy_time = rdy_time
        self.due_date = due_date
        self.service_time = serv_time
    
    def distance(self, node):
        i = self.coordinate
        j = node.coordinate
        diff = (i[0]-j[0], i[1]-j[1])
        return math.sqrt(diff[0]*diff[0]+diff[1]*diff[1])
    
    def travel_time(self,node):
        return round(self.distance(node),1)

# %%
class CPVRTW:
    def __init__(self, file_name, num_nodes):
        self.num_nodes = num_nodes
        self.nodes = []
        f = open(file_name, "r")
        for i in range(4) :
            line = f.readline()    

        line = f.readline()
        data  = re.findall(r"[-+]?\d.\d+|\d+", line)
        self.num_vehicle = int(data[0])
        self.capacity = int(data[1])

        for i in range(4) :
            line = f.readline()    #   | Salto altre 4 linee

        for i in range(num_nodes) :
            line = f.readline()
            data = re.findall(r"[-+]?\d.\d+|\d+", line)
            coordinate = (int(data[1]), int(data[2]))
            demand = int(data[3])
            rdy_time = int(data[4])
            due_date = int(data[5])
            serv_time = int(data[6])
            self.nodes.append(Node(i,coordinate,demand,rdy_time,due_date,serv_time))
        f.close()

        self.calculate_distances()
        self.calculate_travel_times()
    
    def calculate_distances (self):
        self.distances = {(i,j): self.nodes[i].distance(self.nodes[j]) for i in range(self.num_nodes) for j in range(self.num_nodes) if i!=j}

    def calculate_travel_times(self):
        self.travel_times = {(i,j): round(self.distances[i,j],1) for i in range(self.num_nodes) for j in range(self.num_nodes) if i != j}
    
    def calculate_routes_from_model(self,x):
        node = []
        for i in range(1,self.num_nodes):
            if x[0,i]>0:
                node.append(i)

        route = []
        self.routes = []
        for k in node:
            next = k
            route.append(k)
            stop = 1
            while stop:
                for i in range(self.num_nodes):
                    if i==0 and x[next,i] == 1:
                        stop = 0
                    elif x[next,i] == 1:
                        route.append(i)
                        next = i

            self.routes.append(route)
            route = []

# %% [markdown]
# ### Lettura del file e memorizzazione dei dati

# %% [markdown]
# $num\_nodes$  Numero di nodi <br>
# $num\_vehicle$ Numero di veicoli <br>
# $capacity$ Capacità di ogni veicolo (uguale per tutti) <br>
# $demand_i$ Domanda di ogni cliente i da soddisfare <br>
# $time\_window_i$ Finestra temporale di servizio per ogni cliente i <br>
# $coordinate$ Posizione nello spazio di ogni nodo <br>
# $travel\_time_{i,j}$ Tempo di percorrenza per raggiungere il cliente j partendo dal cliente i <br>
# $dist_{i,j}$ Distanza euclidea tra il cliente i e il cliente j

# %%
file_name = "VRPTW-Instances/Solomon/C101.txt"
instance = CPVRTW(file_name, 100)

# %% [markdown]
# ## Modellazione

# %% [markdown]
# ### Variabili

# %% [markdown]
# $x_{i,j}$ Variabile binaria (1 se l'arco è attraversato da un veicolo, 0 altrimenti) <br>
# $u_i$ Quantità di domanda servita dal veicolo nel percorso dal deposito al nodo i <br>
# $a_i$ Tempo di arrivo nel nodo $i$

# %%
mod = gb.Model('CVRP')
x = mod.addVars(range(instance.num_nodes), range(instance.num_nodes),vtype=GRB.BINARY, name="X")
u = mod.addVars(range(instance.num_nodes),vtype=GRB.INTEGER, name="Y")
a = mod.addVars(range(instance.num_nodes), vtype=GRB.INTEGER,name="A")
# Out:
# Academic license - for non-commercial use only - expires 2021-08-10
# Using license file C:\Users\Giuseppe\Universita\x\gurobi.lic

# %% [markdown]
# ### Vincoli

# %% [markdown]
# Se un veicolo entra nel nodo $i$ deve anche uscirne
# $$\sum_{j=0}^{n} x_{i,j} - \sum_{j=0}^{n} x_{j,i} = 0 \quad \forall i \in \{0,1,2,...,n\}$$

# %%
mod.addConstrs((x.sum(i,'*') - x.sum('*',i)  == 0 for i in range(instance.num_nodes)), name="Trasporto");

# %% [markdown]
# Dal deposito devono uscire massimo $m$ veicoli
# $$\sum_{j=1}^{n} x_{0j} \leq m $$

# %%
mod.addConstr(x.sum(0,'*') - x[0,0] <= instance.num_vehicle, name="NumeroVeicoli");

# %% [markdown]
# Ogni cliente deve essere servito da un solo veicolo
# $$\sum_{j=0}^{n} x_{i,j} = 1 \quad \forall  i \in \{1,2,...,n\}$$

# %%
mod.addConstrs((x.sum(i,'*') == 1 for i in range(1,instance.num_nodes)), name="VeicoliCliente");

# %% [markdown]
# Quando il camion arriva al cliente $i$, la domanda totale servita deve essere minore della sua capacità
# $$u_i \leq Q \quad \forall i \in V$$ <br>
# La domanda iniziale (nel nodo 0) deve essere nulla essendo il deposito
# $$u_0 = 0$$

# %%
mod.addConstrs((u[i] <= instance.capacity for i in range(instance.num_nodes)), "CapacitàMassima");
mod.addConstr((u[0] == 0), "DomandaIniziale");

# %% [markdown]
# Si deve evitare di considerare archi ricorsivi (un camion entra in nodo e va nello stesso nodo)
# $$x_{i,i} = 0 \quad \forall i \in {0,1,...,n}$$

# %%
mod.addConstrs((x[i,i] == 0 for i in range(instance.num_nodes)), "ArchiRicorsivi");

# %% [markdown]
# Per permettere il trasporto, dopo che il veicolo è arrivato ad un nodo si deve assicurare che può andare in quello successivo. Bisogna controllare che la richiesta del nodo successivo non supera la capacità corrente del veicolo.

# %% [markdown]
# $$u_j - u_i - d_jx_{i,j} + Q(1-x_{i,j}) \geq 0 \quad \forall i,j \in V, \; i\neq j, \; j \neq 0$$

# %%
mod.addConstrs(u[j] - u[i] - instance.nodes[j].demand*x[i,j] + instance.capacity*(1-x[i,j]) >= 0 for i in range(instance.num_nodes) for j in range(instance.num_nodes) if i!=j and j!=0);

# %% [markdown]
# Un veicolo può arrivare ad un nodo solo se ha completamente servito il nodo precedente
# $$a_j \geq (a_i + t_i + t_{ij}) - (1-x_{ij})T \quad \forall i \in \{0,1,...,n\} \; \forall j \in \{1,2,...,n\} \; i \neq j$$
# T è un tempo molto grande, si può porre pari al massimo tempo per servire tutti i nodi

# %%
mod.addConstrs((a[j] >= (a[i]+instance.nodes[i].service_time+instance.travel_times[i,j]) - (1-x[i,j])*instance.nodes[0].due_date for i in range(instance.num_nodes) for j in range(1,instance.num_nodes) if i!=j),name="TempiDiArrivo");
#mod.addConstrs((a[i] + travel_time[i,0] + serv_time[i] <= time_window[0][1] for i in range(1,num_nodes)),name="TempoDeposito");

# %% [markdown]
# Il tempo di arrivo di ogni nodo deve essere compreso nella finestra temporale
# $$l_i \leq a_i \leq L_i \quad \forall i \in \{0,1,...,n\}$$

# %%
mod.addConstrs((a[i] >= instance.nodes[i].rdy_time for i in range(1,instance.num_nodes)),name="TW_Lower")
mod.addConstrs((a[i] <= instance.nodes[i].due_date for i in range(1,instance.num_nodes)),name="TW_Upper");

# %% [markdown]
# ### Funzione obiettivo

# %% [markdown]
# Minimizzare i costi di trasporto totali
# $$min \sum_{i=1}^{n}\sum_{j=1}^{n} c_{i,j}x_{i,j} \quad i \neq j$$

# %%
obj = (gb.quicksum(instance.distances[i,j]*x[i,j] for i in range(instance.num_nodes) for j in range(instance.num_nodes) if i!=j))
mod.setObjective(obj, GRB.MINIMIZE)

# %%
mod.optimize()
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 20201 rows, 10200 columns and 89004 nonzeros
# Model fingerprint: 0x6201a671
# Variable types: 0 continuous, 10200 integer (10000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 16344 rows and 5618 columns
# Presolve time: 0.24s
# Presolved: 3857 rows, 4582 columns, 20191 nonzeros
# Variable types: 0 continuous, 4582 integer (4411 binary)
#
# Root relaxation: objective 8.201517e+02, 337 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  820.15174    0   44          -  820.15174      -     -    0s
# H    0     0                    1151.1039159  820.15174  28.8%     -    0s
# H    0     0                    1082.5692302  820.15174  24.2%     -    0s
# H    0     0                    1080.0351710  820.15174  24.1%     -    0s
#      0     0  823.33323    0   62 1080.03517  823.33323  23.8%     -    0s
# H    0     0                     937.5578007  823.33323  12.2%     -    0s
# H    0     0                     859.8561567  823.33323  4.25%     -    0s
#      0     0  826.58592    0   91  859.85616  826.58592  3.87%     -    0s
#      0     0  826.58592    0   43  859.85616  826.58592  3.87%     -    1s
#      0     0  826.58592    0  111  859.85616  826.58592  3.87%     -    1s
#      0     0  826.65864    0  102  859.85616  826.65864  3.86%     -    1s
#      0     0  828.26452    0  103  859.85616  828.26452  3.67%     -    1s
# H    0     0                     858.5189689  828.26452  3.52%     -    1s
#      0     0  828.46165    0   49  858.51897  828.46165  3.50%     -    1s
#      0     0  828.81703    0  110  858.51897  828.81703  3.46%     -    1s
#      0     0  828.85336    0  112  858.51897  828.85336  3.46%     -    1s
#      0     0  829.40864    0   59  858.51897  829.40864  3.39%     -    1s
#      0     0  830.27301    0   58  858.51897  830.27301  3.29%     -    1s
#      0     0  830.32422    0  101  858.51897  830.32422  3.28%     -    1s
#      0     0  830.50419    0  104  858.51897  830.50419  3.26%     -    1s
#      0     0  830.50419    0  105  858.51897  830.50419  3.26%     -    1s
#      0     0  830.66047    0  112  858.51897  830.66047  3.24%     -    1s
#      0     0  830.80810    0   84  858.51897  830.80810  3.23%     -    1s
#      0     0  830.80810    0   84  858.51897  830.80810  3.23%     -    1s
#      0     0  830.98471    0   62  858.51897  830.98471  3.21%     -    1s
#      0     0  830.98471    0   62  858.51897  830.98471  3.21%     -    1s
#      0     0  830.98471    0   61  858.51897  830.98471  3.21%     -    1s
#      0     0  831.31126    0   74  858.51897  831.31126  3.17%     -    1s
#      0     0  831.75278    0   36  858.51897  831.75278  3.12%     -    1s
#      0     0  831.75278    0   36  858.51897  831.75278  3.12%     -    1s
# H    0     0                     845.3228629  831.75278  1.61%     -    1s
#      0     0  831.81879    0   42  845.32286  831.81879  1.60%     -    1s
#      0     0     cutoff    0       845.32286  845.32286  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 2
#   Implied bound: 18
#   Clique: 11
#   MIR: 2
#   StrongCG: 1
#   RLT: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (1310 simplex iterations) in 1.92 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 9: 845.323 845.323 858.519 ... 1151.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.453228628885e+02, best bound 8.453228628885e+02, gap 0.0000%

# %% [markdown]
# ## Grafico

# %%
Graph = nx.DiGraph()
list_nodes = list(range(instance.num_nodes))
Graph.add_nodes_from(list_nodes)
for i in range(instance.num_nodes):
    for j in range(instance.num_nodes) :
        if i!=j and x[i,j].x == 1 :
            Graph.add_edge(i,j)

dict_dem = {}
for i in range(instance.num_nodes) :
    dict_dem[i] = instance.nodes[i].demand
coordinate = {}
for i in range(instance.num_nodes):
     coordinate[i] = instance.nodes[i].coordinate
# Colora di rosso i nodi della soluzione e di verde gli altri
node_col = ['purple' for node in Graph.nodes()]
# Colora di rosso gli archi della soluzione e di nero gli altri
edge_col = ['black' for edge in Graph.edges()]
# Draw the nodes
nx.draw_networkx(Graph,coordinate, node_color= node_col, node_size=500)
# Draw the edges
nx.draw_networkx_edges(Graph, coordinate,edge_color= edge_col)
# Show the plot
#nx.draw_networkx_labels(Graph,coordinate,labels= dict_dem,horizontalalignment='center',verticalalignment='bottom')

plt.show()

# %%
X = mod.getAttr('x', x)
instance.calculate_routes_from_model(X)
for i in range(len(instance.routes)) :
    print(instance.routes[i])
# Out:
# [5, 3, 7, 8, 10, 11, 9, 6, 4, 1, 75]
# [13, 17, 18, 19, 15, 16, 14, 12]
# [20, 24, 25, 27, 29, 30, 28, 26, 23, 22, 21]
# [32, 33, 31, 35, 37, 38, 39, 36, 34]
# [43, 42, 41, 40, 44, 46, 45, 48, 51, 50, 52, 49]
# [57, 55, 54, 53, 56, 58, 60, 59]
# [67, 65, 63, 62, 74, 72, 61, 64, 68, 66]
# [81, 78, 76, 71, 70, 73, 77, 79, 80, 69, 47]
# [90, 87, 86, 83, 82, 84, 85, 88, 89, 91]
# [98, 96, 95, 94, 92, 93, 97, 99, 2]

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Algoritmo Genetico

# %% [markdown]
# ## Ricerca delle soluzioni iniziali

# %%
def nodi_raggiungibili(lista_nodi, nodo_iniziale, tempo_iniziale, capacita_rimanente, tolleranza):
    ragg_nodes = []
    for k in lista_nodi:
        node = k
        if nodo_iniziale.number != node.number:
            if node.demand < capacita_rimanente:
                tt = node.travel_time(nodo_iniziale) + nodo_iniziale.service_time + tempo_iniziale
                if tt < node.due_date and tt > node.rdy_time-tolleranza:
                    print("Nodo: ",node.number,"\t[",node.rdy_time,", ",node.due_date,"] \t- Travel and Service Time: ", tt)
                    ragg_nodes.append(node)
    return ragg_nodes

# %%
ragg_nodes = []
solution = []
times = [] #Lista dei tempi di arrivo in ogni nodo
list_nodes = []
for i in range(instance.num_nodes):
    list_nodes.append(instance.nodes[i])
deposito = list_nodes[0]
list_nodes.remove(deposito)
solution.append(deposito)

remain_capacity = instance.capacity
next_node = deposito
route_time = 0
k = 1
print("Veicolo: ",k)
stp = 1
wait_time = 0
stp_ext = 1
while stp_ext == 1:
    while stp == 1:
        
        ragg_nodes = nodi_raggiungibili(list_nodes, next_node, route_time, remain_capacity, 100)
        if len(ragg_nodes) == 0:
            print("Nessun nodo raggiungibile")
            solution.append(deposito)
            remain_capacity = instance.capacity
            next_node = deposito
            route_time = 0
            k = k+1
            if k > instance.num_vehicle:
                stp = 0
                k=0
            print("\n\nVeicolo: ",k)
        else:
            from_node = next_node
            print("Nodo iniziale: ", from_node.number)
            next_node = random.choice(ragg_nodes)
            print("Prossimo nodo: ",next_node.number, "Richiesta: ", next_node.demand)
            remain_capacity -= next_node.demand
            print("Capacità rimanente: ",remain_capacity)
            route_time = route_time + from_node.service_time + from_node.travel_time(next_node)
            wait_time = next_node.rdy_time - route_time
            if wait_time < 0: #Il veicolo è arrivato in tempo
                wait_time = 0
            route_time += wait_time
            times.append(route_time)
            print("Tempo corrente: ",route_time)
            print("Tempo di attesa: ",wait_time)
            solution.append(next_node)
            list_nodes.remove(next_node)
            if len(list_nodes) == 0:
                stp = 2
    if stp == 2:
        stp_ext = 0
    else:
        solution = []
        list_nodes = []
        times = []
        for i in range(instance.num_nodes):
            list_nodes.append(instance.nodes[i]) 
        deposito = list_nodes[0]
        list_nodes.remove(deposito)
        solution.append(deposito)
        stp = 1
# Out:
# Veicolo:  1
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  17 	[ 99 ,  148 ] 	- Travel and Service Time:  33.3
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  24 	[ 65 ,  144 ] 	- Travel and Service Time:  15.0
# Nodo:  32 	[ 31 ,  100 ] 	- Travel and Service Time:  31.6
# Nodo:  33 	[ 87 ,  158 ] 	- Travel and Service Time:  33.5
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  43 	[ 16 ,  80 ] 	- Travel and Service Time:  16.6
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  57 	[ 35 ,  87 ] 	- Travel and Service Time:  35.0
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  12.8
# Nodo:  67 	[ 12 ,  77 ] 	- Travel and Service Time:  12.2
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  87 	[ 85 ,  144 ] 	- Travel and Service Time:  25.5
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo:  98 	[ 30 ,  84 ] 	- Travel and Service Time:  30.8
# Nodo iniziale:  0
# Prossimo nodo:  87 Richiesta:  20
# Capacità rimanente:  180
# Tempo corrente:  85.0
# Tempo di attesa:  59.5
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  202.3
# Nodo:  8 	[ 255 ,  324 ] 	- Travel and Service Time:  205.0
# Nodo:  18 	[ 179 ,  254 ] 	- Travel and Service Time:  228.9
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  230.9
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  215.1
# Nodo:  27 	[ 261 ,  316 ] 	- Travel and Service Time:  217.1
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  233.5
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  238.2
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  214.1
# Nodo:  41 	[ 166 ,  235 ] 	- Travel and Service Time:  212.8
# Nodo:  53 	[ 286 ,  347 ] 	- Travel and Service Time:  229.2
# Nodo:  54 	[ 186 ,  257 ] 	- Travel and Service Time:  225.5
# Nodo:  62 	[ 262 ,  317 ] 	- Travel and Service Time:  200.0
# Nodo:  63 	[ 171 ,  218 ] 	- Travel and Service Time:  196.2
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  211.1
# Nodo:  76 	[ 203 ,  260 ] 	- Travel and Service Time:  207.0
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  182.0
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  176.0
# Nodo:  94 	[ 285 ,  336 ] 	- Travel and Service Time:  202.0
# Nodo:  95 	[ 196 ,  239 ] 	- Travel and Service Time:  200.2
# Nodo iniziale:  87
# Prossimo nodo:  76 Richiesta:  10
# Capacità rimanente:  170
# Tempo corrente:  207.0
# Tempo di attesa:  0
# Nodo:  10 	[ 357 ,  410 ] 	- Travel and Service Time:  360.1
# Nodo:  11 	[ 448 ,  505 ] 	- Travel and Service Time:  361.7
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  380.2
# Nodo:  16 	[ 475 ,  528 ] 	- Travel and Service Time:  383.0
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  368.6
# Nodo:  30 	[ 449 ,  504 ] 	- Travel and Service Time:  369.8
# Nodo:  37 	[ 383 ,  434 ] 	- Travel and Service Time:  385.1
# Nodo:  38 	[ 479 ,  522 ] 	- Travel and Service Time:  387.1
# Nodo:  44 	[ 359 ,  412 ] 	- Travel and Service Time:  355.2
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  357.1
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  355.3
# Nodo:  70 	[ 387 ,  456 ] 	- Travel and Service Time:  304.1
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  302.0
# Nodo:  74 	[ 353 ,  412 ] 	- Travel and Service Time:  334.0
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  322.0
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  323.9
# Nodo:  92 	[ 368 ,  441 ] 	- Travel and Service Time:  352.0
# Nodo iniziale:  76
# Prossimo nodo:  38 Richiesta:  30
# Capacità rimanente:  140
# Tempo corrente:  479.0
# Tempo di attesa:  91.89999999999998
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  618.4
# Nodo:  12 	[ 652 ,  721 ] 	- Travel and Service Time:  620.5
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  619.1
# Nodo:  26 	[ 622 ,  701 ] 	- Travel and Service Time:  598.2
# Nodo:  36 	[ 665 ,  716 ] 	- Travel and Service Time:  576.1
# Nodo:  39 	[ 567 ,  624 ] 	- Travel and Service Time:  574.0
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  598.7
# Nodo:  59 	[ 651 ,  740 ] 	- Travel and Service Time:  614.5
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  618.5
# Nodo:  64 	[ 632 ,  693 ] 	- Travel and Service Time:  618.0
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  656.6
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  637.0
# Nodo iniziale:  38
# Prossimo nodo:  59 Richiesta:  10
# Capacità rimanente:  130
# Tempo corrente:  651.0
# Tempo di attesa:  36.5
# Nodo:  2 	[ 825 ,  870 ] 	- Travel and Service Time:  796.4
# Nodo:  22 	[ 812 ,  883 ] 	- Travel and Service Time:  779.3
# Nodo:  34 	[ 751 ,  816 ] 	- Travel and Service Time:  783.4
# Nodo:  50 	[ 815 ,  880 ] 	- Travel and Service Time:  761.8
# Nodo:  51 	[ 725 ,  786 ] 	- Travel and Service Time:  760.8
# Nodo:  66 	[ 826 ,  875 ] 	- Travel and Service Time:  762.9
# Nodo:  68 	[ 734 ,  777 ] 	- Travel and Service Time:  757.6
# Nodo:  80 	[ 769 ,  820 ] 	- Travel and Service Time:  789.1
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  790.7
# Nodo:  91 	[ 836 ,  889 ] 	- Travel and Service Time:  791.1
# Nodo:  99 	[ 743 ,  820 ] 	- Travel and Service Time:  808.2
# Nodo iniziale:  59
# Prossimo nodo:  66 Richiesta:  10
# Capacità rimanente:  120
# Tempo corrente:  826.0
# Tempo di attesa:  63.10000000000002
# Nodo:  1 	[ 912 ,  967 ] 	- Travel and Service Time:  949.1
# Nodo:  21 	[ 914 ,  965 ] 	- Travel and Service Time:  940.0
# Nodo:  49 	[ 1001 ,  1066 ] 	- Travel and Service Time:  935.0
# Nodo:  52 	[ 912 ,  969 ] 	- Travel and Service Time:  938.0
# Nodo:  69 	[ 916 ,  969 ] 	- Travel and Service Time:  918.0
# Nodo:  75 	[ 997 ,  1068 ] 	- Travel and Service Time:  946.1
# Nodo iniziale:  66
# Prossimo nodo:  75 Richiesta:  20
# Capacità rimanente:  100
# Tempo corrente:  997.0
# Tempo di attesa:  50.89999999999998
# Nodo:  47 	[ 1054 ,  1127 ] 	- Travel and Service Time:  1120.5
# Nodo iniziale:  75
# Prossimo nodo:  47 Richiesta:  10
# Capacità rimanente:  90
# Tempo corrente:  1120.5
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  2
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  17 	[ 99 ,  148 ] 	- Travel and Service Time:  33.3
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  24 	[ 65 ,  144 ] 	- Travel and Service Time:  15.0
# Nodo:  32 	[ 31 ,  100 ] 	- Travel and Service Time:  31.6
# Nodo:  33 	[ 87 ,  158 ] 	- Travel and Service Time:  33.5
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  43 	[ 16 ,  80 ] 	- Travel and Service Time:  16.6
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  57 	[ 35 ,  87 ] 	- Travel and Service Time:  35.0
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  12.8
# Nodo:  67 	[ 12 ,  77 ] 	- Travel and Service Time:  12.2
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo:  98 	[ 30 ,  84 ] 	- Travel and Service Time:  30.8
# Nodo iniziale:  0
# Prossimo nodo:  24 Richiesta:  10
# Capacità rimanente:  190
# Tempo corrente:  65.0
# Tempo di attesa:  50.0
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  176.9
# Nodo:  8 	[ 255 ,  324 ] 	- Travel and Service Time:  177.2
# Nodo:  18 	[ 179 ,  254 ] 	- Travel and Service Time:  181.9
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  186.6
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  157.0
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  176.2
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  177.4
# Nodo:  41 	[ 166 ,  235 ] 	- Travel and Service Time:  175.6
# Nodo:  53 	[ 286 ,  347 ] 	- Travel and Service Time:  203.8
# Nodo:  54 	[ 186 ,  257 ] 	- Travel and Service Time:  198.5
# Nodo:  62 	[ 262 ,  317 ] 	- Travel and Service Time:  184.2
# Nodo:  63 	[ 171 ,  218 ] 	- Travel and Service Time:  181.9
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  226.6
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  202.3
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  196.3
# Nodo:  94 	[ 285 ,  336 ] 	- Travel and Service Time:  206.2
# Nodo:  95 	[ 196 ,  239 ] 	- Travel and Service Time:  202.6
# Nodo iniziale:  24
# Prossimo nodo:  18 Richiesta:  20
# Capacità rimanente:  170
# Tempo corrente:  181.9
# Tempo di attesa:  0
# Nodo:  8 	[ 255 ,  324 ] 	- Travel and Service Time:  295.9
# Nodo:  10 	[ 357 ,  410 ] 	- Travel and Service Time:  293.8
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  276.9
# Nodo:  27 	[ 261 ,  316 ] 	- Travel and Service Time:  296.3
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  297.4
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  313.1
# Nodo:  37 	[ 383 ,  434 ] 	- Travel and Service Time:  309.2
# Nodo:  44 	[ 359 ,  412 ] 	- Travel and Service Time:  320.0
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  346.20000000000005
# Nodo:  70 	[ 387 ,  456 ] 	- Travel and Service Time:  363.70000000000005
# Nodo:  74 	[ 353 ,  412 ] 	- Travel and Service Time:  327.1
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  335.1
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  332.3
# Nodo:  92 	[ 368 ,  441 ] 	- Travel and Service Time:  324.9
# Nodo:  94 	[ 285 ,  336 ] 	- Travel and Service Time:  322.4
# Nodo iniziale:  18
# Prossimo nodo:  37 Richiesta:  20
# Capacità rimanente:  150
# Tempo corrente:  383.0
# Tempo di attesa:  73.80000000000001
# Nodo:  9 	[ 534 ,  605 ] 	- Travel and Service Time:  519.9
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  522.2
# Nodo:  16 	[ 475 ,  528 ] 	- Travel and Service Time:  521.5
# Nodo:  28 	[ 546 ,  593 ] 	- Travel and Service Time:  498.8
# Nodo:  30 	[ 449 ,  504 ] 	- Travel and Service Time:  496.4
# Nodo:  39 	[ 567 ,  624 ] 	- Travel and Service Time:  478.4
# Nodo:  45 	[ 541 ,  600 ] 	- Travel and Service Time:  502.7
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  502.1
# Nodo:  58 	[ 471 ,  534 ] 	- Travel and Service Time:  523.2
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  521.1
# Nodo:  61 	[ 531 ,  610 ] 	- Travel and Service Time:  522.0
# Nodo:  77 	[ 574 ,  643 ] 	- Travel and Service Time:  559.6
# Nodo:  85 	[ 555 ,  612 ] 	- Travel and Service Time:  542.0
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  546.4
# Nodo iniziale:  37
# Prossimo nodo:  30 Richiesta:  10
# Capacità rimanente:  140
# Tempo corrente:  496.4
# Tempo di attesa:  0
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  610.8
# Nodo:  12 	[ 652 ,  721 ] 	- Travel and Service Time:  616.8
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  616.5
# Nodo:  26 	[ 622 ,  701 ] 	- Travel and Service Time:  591.4
# Nodo:  28 	[ 546 ,  593 ] 	- Travel and Service Time:  589.4
# Nodo:  36 	[ 665 ,  716 ] 	- Travel and Service Time:  604.4
# Nodo:  39 	[ 567 ,  624 ] 	- Travel and Service Time:  608.8
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  612.6
# Nodo:  64 	[ 632 ,  693 ] 	- Travel and Service Time:  623.9
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  657.9
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  631.7
# Nodo iniziale:  30
# Prossimo nodo:  12 Richiesta:  20
# Capacità rimanente:  120
# Tempo corrente:  652.0
# Tempo di attesa:  35.200000000000045
# Nodo:  2 	[ 825 ,  870 ] 	- Travel and Service Time:  767.0
# Nodo:  4 	[ 727 ,  782 ] 	- Travel and Service Time:  766.0
# Nodo:  22 	[ 812 ,  883 ] 	- Travel and Service Time:  775.1
# Nodo:  23 	[ 732 ,  777 ] 	- Travel and Service Time:  772.1
# Nodo:  34 	[ 751 ,  816 ] 	- Travel and Service Time:  785.5
# Nodo:  50 	[ 815 ,  880 ] 	- Travel and Service Time:  795.0
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  788.6
# Nodo:  91 	[ 836 ,  889 ] 	- Travel and Service Time:  785.0
# Nodo:  99 	[ 743 ,  820 ] 	- Travel and Service Time:  772.4
# Nodo iniziale:  12
# Prossimo nodo:  99 Richiesta:  10
# Capacità rimanente:  110
# Tempo corrente:  772.4
# Tempo di attesa:  0
# Nodo:  1 	[ 912 ,  967 ] 	- Travel and Service Time:  878.0
# Nodo:  21 	[ 914 ,  965 ] 	- Travel and Service Time:  899.9
# Nodo:  49 	[ 1001 ,  1066 ] 	- Travel and Service Time:  914.9
# Nodo:  52 	[ 912 ,  969 ] 	- Travel and Service Time:  916.5
# Nodo:  69 	[ 916 ,  969 ] 	- Travel and Service Time:  908.5
# Nodo:  91 	[ 836 ,  889 ] 	- Travel and Service Time:  883.0
# Nodo iniziale:  99
# Prossimo nodo:  21 Richiesta:  20
# Capacità rimanente:  90
# Tempo corrente:  914.0
# Tempo di attesa:  14.100000000000023
# Nodo:  49 	[ 1001 ,  1066 ] 	- Travel and Service Time:  1021.1
# Nodo iniziale:  21
# Prossimo nodo:  49 Richiesta:  10
# Capacità rimanente:  80
# Tempo corrente:  1021.1
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  3
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  17 	[ 99 ,  148 ] 	- Travel and Service Time:  33.3
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  32 	[ 31 ,  100 ] 	- Travel and Service Time:  31.6
# Nodo:  33 	[ 87 ,  158 ] 	- Travel and Service Time:  33.5
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  43 	[ 16 ,  80 ] 	- Travel and Service Time:  16.6
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  57 	[ 35 ,  87 ] 	- Travel and Service Time:  35.0
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  12.8
# Nodo:  67 	[ 12 ,  77 ] 	- Travel and Service Time:  12.2
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo:  98 	[ 30 ,  84 ] 	- Travel and Service Time:  30.8
# Nodo iniziale:  0
# Prossimo nodo:  67 Richiesta:  10
# Capacità rimanente:  190
# Tempo corrente:  12.2
# Tempo di attesa:  0
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  128.7
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  129.1
# Nodo:  17 	[ 99 ,  148 ] 	- Travel and Service Time:  147.7
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  127.3
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  139.5
# Nodo:  33 	[ 87 ,  158 ] 	- Travel and Service Time:  141.2
# Nodo:  41 	[ 166 ,  235 ] 	- Travel and Service Time:  116.60000000000001
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  118.3
# Nodo:  54 	[ 186 ,  257 ] 	- Travel and Service Time:  132.6
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  127.7
# Nodo:  63 	[ 171 ,  218 ] 	- Travel and Service Time:  105.2
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  103.2
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  143.5
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  126.4
# Nodo:  95 	[ 196 ,  239 ] 	- Travel and Service Time:  144.89999999999998
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  144.29999999999998
# Nodo iniziale:  67
# Prossimo nodo:  41 Richiesta:  10
# Capacità rimanente:  180
# Tempo corrente:  166.0
# Tempo di attesa:  49.39999999999999
# Nodo:  8 	[ 255 ,  324 ] 	- Travel and Service Time:  292.1
# Nodo:  10 	[ 357 ,  410 ] 	- Travel and Service Time:  290.0
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  306.3
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  308.0
# Nodo:  27 	[ 261 ,  316 ] 	- Travel and Service Time:  279.3
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  279.4
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  286.1
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  258.0
# Nodo:  44 	[ 359 ,  412 ] 	- Travel and Service Time:  259.6
# Nodo:  53 	[ 286 ,  347 ] 	- Travel and Service Time:  284.5
# Nodo:  62 	[ 262 ,  317 ] 	- Travel and Service Time:  271.3
# Nodo:  70 	[ 387 ,  456 ] 	- Travel and Service Time:  316.0
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  316.1
# Nodo:  74 	[ 353 ,  412 ] 	- Travel and Service Time:  274.2
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  302.1
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  299.6
# Nodo:  92 	[ 368 ,  441 ] 	- Travel and Service Time:  317.9
# Nodo:  94 	[ 285 ,  336 ] 	- Travel and Service Time:  314.3
# Nodo iniziale:  41
# Prossimo nodo:  74 Richiesta:  50
# Capacità rimanente:  130
# Tempo corrente:  353.0
# Tempo di attesa:  78.80000000000001
# Nodo:  9 	[ 534 ,  605 ] 	- Travel and Service Time:  481.1
# Nodo:  11 	[ 448 ,  505 ] 	- Travel and Service Time:  481.5
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  501.8
# Nodo:  16 	[ 475 ,  528 ] 	- Travel and Service Time:  502.9
# Nodo:  28 	[ 546 ,  593 ] 	- Travel and Service Time:  479.1
# Nodo:  39 	[ 567 ,  624 ] 	- Travel and Service Time:  496.9
# Nodo:  45 	[ 541 ,  600 ] 	- Travel and Service Time:  466.5
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  466.2
# Nodo:  58 	[ 471 ,  534 ] 	- Travel and Service Time:  476.5
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  478.0
# Nodo:  61 	[ 531 ,  610 ] 	- Travel and Service Time:  448.8
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  448.0
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  482.3
# Nodo:  77 	[ 574 ,  643 ] 	- Travel and Service Time:  478.4
# Nodo:  84 	[ 458 ,  523 ] 	- Travel and Service Time:  471.6
# Nodo:  85 	[ 555 ,  612 ] 	- Travel and Service Time:  472.2
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  494.4
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  493.5
# Nodo iniziale:  74
# Prossimo nodo:  11 Richiesta:  10
# Capacità rimanente:  120
# Tempo corrente:  481.5
# Tempo di attesa:  0
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  576.5
# Nodo:  9 	[ 534 ,  605 ] 	- Travel and Service Time:  574.7
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  592.1
# Nodo:  26 	[ 622 ,  701 ] 	- Travel and Service Time:  588.7
# Nodo:  28 	[ 546 ,  593 ] 	- Travel and Service Time:  589.9
# Nodo:  36 	[ 665 ,  716 ] 	- Travel and Service Time:  609.9
# Nodo:  39 	[ 567 ,  624 ] 	- Travel and Service Time:  613.9
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  611.1
# Nodo:  64 	[ 632 ,  693 ] 	- Travel and Service Time:  612.6
# Nodo:  77 	[ 574 ,  643 ] 	- Travel and Service Time:  637.3
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  636.5
# Nodo:  85 	[ 555 ,  612 ] 	- Travel and Service Time:  605.7
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  602.8
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  601.2
# Nodo iniziale:  11
# Prossimo nodo:  26 Richiesta:  10
# Capacità rimanente:  110
# Tempo corrente:  622.0
# Tempo di attesa:  33.299999999999955
# Nodo:  2 	[ 825 ,  870 ] 	- Travel and Service Time:  737.0
# Nodo:  4 	[ 727 ,  782 ] 	- Travel and Service Time:  733.4
# Nodo:  22 	[ 812 ,  883 ] 	- Travel and Service Time:  716.2
# Nodo:  23 	[ 732 ,  777 ] 	- Travel and Service Time:  715.0
# Nodo:  34 	[ 751 ,  816 ] 	- Travel and Service Time:  731.7
# Nodo:  50 	[ 815 ,  880 ] 	- Travel and Service Time:  735.0
# Nodo:  51 	[ 725 ,  786 ] 	- Travel and Service Time:  737.0
# Nodo:  68 	[ 734 ,  777 ] 	- Travel and Service Time:  744.0
# Nodo:  80 	[ 769 ,  820 ] 	- Travel and Service Time:  779.1
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  750.1
# Nodo:  91 	[ 836 ,  889 ] 	- Travel and Service Time:  747.4
# Nodo iniziale:  26
# Prossimo nodo:  91 Richiesta:  10
# Capacità rimanente:  100
# Tempo corrente:  836.0
# Tempo di attesa:  88.60000000000002
# Nodo:  1 	[ 912 ,  967 ] 	- Travel and Service Time:  943.0
# Nodo:  69 	[ 916 ,  969 ] 	- Travel and Service Time:  955.2
# Nodo iniziale:  91
# Prossimo nodo:  1 Richiesta:  10
# Capacità rimanente:  90
# Tempo corrente:  943.0
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  4
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  17 	[ 99 ,  148 ] 	- Travel and Service Time:  33.3
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  32 	[ 31 ,  100 ] 	- Travel and Service Time:  31.6
# Nodo:  33 	[ 87 ,  158 ] 	- Travel and Service Time:  33.5
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  43 	[ 16 ,  80 ] 	- Travel and Service Time:  16.6
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  57 	[ 35 ,  87 ] 	- Travel and Service Time:  35.0
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  12.8
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo:  98 	[ 30 ,  84 ] 	- Travel and Service Time:  30.8
# Nodo iniziale:  0
# Prossimo nodo:  57 Richiesta:  40
# Capacità rimanente:  160
# Tempo corrente:  35.0
# Tempo di attesa:  0.0
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  176.0
# Nodo:  8 	[ 255 ,  324 ] 	- Travel and Service Time:  178.0
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  194.6
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  164.9
# Nodo:  27 	[ 261 ,  316 ] 	- Travel and Service Time:  165.7
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  161.1
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  143.4
# Nodo:  54 	[ 186 ,  257 ] 	- Travel and Service Time:  130.4
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  127.0
# Nodo:  63 	[ 171 ,  218 ] 	- Travel and Service Time:  151.9
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  176.2
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  172.7
# Nodo:  94 	[ 285 ,  336 ] 	- Travel and Service Time:  196.5
# Nodo:  95 	[ 196 ,  239 ] 	- Travel and Service Time:  193.6
# Nodo iniziale:  57
# Prossimo nodo:  95 Richiesta:  30
# Capacità rimanente:  130
# Tempo corrente:  196.0
# Tempo di attesa:  2.4000000000000057
# Nodo:  8 	[ 255 ,  324 ] 	- Travel and Service Time:  312.8
# Nodo:  10 	[ 357 ,  410 ] 	- Travel and Service Time:  316.4
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  328.0
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  333.0
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  337.6
# Nodo:  44 	[ 359 ,  412 ] 	- Travel and Service Time:  344.3
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  364.2
# Nodo:  70 	[ 387 ,  456 ] 	- Travel and Service Time:  345.9
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  341.8
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  314.2
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  312.9
# Nodo:  92 	[ 368 ,  441 ] 	- Travel and Service Time:  293.1
# Nodo:  94 	[ 285 ,  336 ] 	- Travel and Service Time:  289.6
# Nodo iniziale:  95
# Prossimo nodo:  8 Richiesta:  20
# Capacità rimanente:  110
# Tempo corrente:  312.8
# Tempo di attesa:  0
# Nodo:  10 	[ 357 ,  410 ] 	- Travel and Service Time:  406.4
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  424.4
# Nodo:  16 	[ 475 ,  528 ] 	- Travel and Service Time:  427.6
# Nodo:  45 	[ 541 ,  600 ] 	- Travel and Service Time:  441.6
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  439.70000000000005
# Nodo:  58 	[ 471 ,  534 ] 	- Travel and Service Time:  465.8
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  465.9
# Nodo:  61 	[ 531 ,  610 ] 	- Travel and Service Time:  442.6
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  443.70000000000005
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  468.8
# Nodo:  84 	[ 458 ,  523 ] 	- Travel and Service Time:  436.3
# Nodo:  92 	[ 368 ,  441 ] 	- Travel and Service Time:  436.4
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  434.70000000000005
# Nodo iniziale:  8
# Prossimo nodo:  16 Richiesta:  40
# Capacità rimanente:  70
# Tempo corrente:  475.0
# Tempo di attesa:  47.39999999999998
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  590.6
# Nodo:  9 	[ 534 ,  605 ] 	- Travel and Service Time:  588.4
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  567.0
# Nodo:  36 	[ 665 ,  716 ] 	- Travel and Service Time:  607.7
# Nodo:  39 	[ 567 ,  624 ] 	- Travel and Service Time:  609.7
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  620.6
# Nodo:  64 	[ 632 ,  693 ] 	- Travel and Service Time:  626.7
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  651.7
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  616.5
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  605.0
# Nodo iniziale:  16
# Prossimo nodo:  39 Richiesta:  20
# Capacità rimanente:  50
# Tempo corrente:  609.7
# Tempo di attesa:  0
# Nodo:  2 	[ 825 ,  870 ] 	- Travel and Service Time:  751.2
# Nodo:  4 	[ 727 ,  782 ] 	- Travel and Service Time:  747.6
# Nodo:  22 	[ 812 ,  883 ] 	- Travel and Service Time:  728.6
# Nodo:  23 	[ 732 ,  777 ] 	- Travel and Service Time:  729.4000000000001
# Nodo:  34 	[ 751 ,  816 ] 	- Travel and Service Time:  707.7
# Nodo:  36 	[ 665 ,  716 ] 	- Travel and Service Time:  704.7
# Nodo:  50 	[ 815 ,  880 ] 	- Travel and Service Time:  728.8000000000001
# Nodo:  51 	[ 725 ,  786 ] 	- Travel and Service Time:  728.9000000000001
# Nodo:  68 	[ 734 ,  777 ] 	- Travel and Service Time:  747.1
# Nodo:  80 	[ 769 ,  820 ] 	- Travel and Service Time:  787.0
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  764.0
# Nodo iniziale:  39
# Prossimo nodo:  80 Richiesta:  10
# Capacità rimanente:  40
# Tempo corrente:  787.0
# Tempo di attesa:  0
# Nodo:  52 	[ 912 ,  969 ] 	- Travel and Service Time:  937.8
# Nodo:  69 	[ 916 ,  969 ] 	- Travel and Service Time:  918.2
# Nodo iniziale:  80
# Prossimo nodo:  52 Richiesta:  10
# Capacità rimanente:  30
# Tempo corrente:  937.8
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  5
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  17 	[ 99 ,  148 ] 	- Travel and Service Time:  33.3
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  32 	[ 31 ,  100 ] 	- Travel and Service Time:  31.6
# Nodo:  33 	[ 87 ,  158 ] 	- Travel and Service Time:  33.5
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  43 	[ 16 ,  80 ] 	- Travel and Service Time:  16.6
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  12.8
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo:  98 	[ 30 ,  84 ] 	- Travel and Service Time:  30.8
# Nodo iniziale:  0
# Prossimo nodo:  98 Richiesta:  20
# Capacità rimanente:  180
# Tempo corrente:  30.8
# Tempo di attesa:  0
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  139.20000000000002
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  140.9
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  161.0
# Nodo:  27 	[ 261 ,  316 ] 	- Travel and Service Time:  162.70000000000002
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  183.3
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  187.20000000000002
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  171.3
# Nodo:  53 	[ 286 ,  347 ] 	- Travel and Service Time:  192.20000000000002
# Nodo:  54 	[ 186 ,  257 ] 	- Travel and Service Time:  187.70000000000002
# Nodo:  63 	[ 171 ,  218 ] 	- Travel and Service Time:  156.70000000000002
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  142.3
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  126.2
# Nodo iniziale:  98
# Prossimo nodo:  53 Richiesta:  20
# Capacità rimanente:  160
# Tempo corrente:  286.0
# Tempo di attesa:  93.80000000000001
# Nodo:  9 	[ 534 ,  605 ] 	- Travel and Service Time:  441.3
# Nodo:  44 	[ 359 ,  412 ] 	- Travel and Service Time:  403.7
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  406.4
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  380.0
# Nodo:  58 	[ 471 ,  534 ] 	- Travel and Service Time:  382.0
# Nodo:  70 	[ 387 ,  456 ] 	- Travel and Service Time:  432.8
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  402.6
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  430.1
# Nodo:  84 	[ 458 ,  523 ] 	- Travel and Service Time:  435.0
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  458.7
# Nodo iniziale:  53
# Prossimo nodo:  58 Richiesta:  30
# Capacità rimanente:  130
# Tempo corrente:  471.0
# Tempo di attesa:  89.0
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  625.0
# Nodo:  36 	[ 665 ,  716 ] 	- Travel and Service Time:  612.9
# Nodo:  45 	[ 541 ,  600 ] 	- Travel and Service Time:  587.2
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  587.9
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  564.0
# Nodo:  61 	[ 531 ,  610 ] 	- Travel and Service Time:  588.7
# Nodo:  64 	[ 632 ,  693 ] 	- Travel and Service Time:  587.9
# Nodo:  77 	[ 574 ,  643 ] 	- Travel and Service Time:  616.9
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  616.0
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  622.3
# Nodo iniziale:  58
# Prossimo nodo:  64 Richiesta:  10
# Capacità rimanente:  120
# Tempo corrente:  632.0
# Tempo di attesa:  44.10000000000002
# Nodo:  2 	[ 825 ,  870 ] 	- Travel and Service Time:  762.1
# Nodo:  4 	[ 727 ,  782 ] 	- Travel and Service Time:  760.5
# Nodo:  22 	[ 812 ,  883 ] 	- Travel and Service Time:  751.7
# Nodo:  23 	[ 732 ,  777 ] 	- Travel and Service Time:  754.0
# Nodo:  34 	[ 751 ,  816 ] 	- Travel and Service Time:  764.7
# Nodo:  50 	[ 815 ,  880 ] 	- Travel and Service Time:  744.1
# Nodo:  51 	[ 725 ,  786 ] 	- Travel and Service Time:  745.0
# Nodo:  68 	[ 734 ,  777 ] 	- Travel and Service Time:  725.0
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  753.8
# Nodo iniziale:  64
# Prossimo nodo:  34 Richiesta:  20
# Capacità rimanente:  100
# Tempo corrente:  764.7
# Tempo di attesa:  0
# Nodo:  22 	[ 812 ,  883 ] 	- Travel and Service Time:  875.9000000000001
# Nodo:  50 	[ 815 ,  880 ] 	- Travel and Service Time:  876.9000000000001
# Nodo:  69 	[ 916 ,  969 ] 	- Travel and Service Time:  893.0
# Nodo iniziale:  34
# Prossimo nodo:  69 Richiesta:  10
# Capacità rimanente:  90
# Tempo corrente:  916.0
# Tempo di attesa:  23.0
# Nessun nodo raggiungibile
#
#
# Veicolo:  6
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  17 	[ 99 ,  148 ] 	- Travel and Service Time:  33.3
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  32 	[ 31 ,  100 ] 	- Travel and Service Time:  31.6
# Nodo:  33 	[ 87 ,  158 ] 	- Travel and Service Time:  33.5
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  43 	[ 16 ,  80 ] 	- Travel and Service Time:  16.6
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  12.8
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  33 Richiesta:  40
# Capacità rimanente:  160
# Tempo corrente:  87.0
# Tempo di attesa:  53.5
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  218.2
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  217.6
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  197.8
# Nodo:  27 	[ 261 ,  316 ] 	- Travel and Service Time:  196.2
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  182.4
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  205.8
# Nodo:  54 	[ 186 ,  257 ] 	- Travel and Service Time:  222.3
# Nodo:  62 	[ 262 ,  317 ] 	- Travel and Service Time:  219.3
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  264.1
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  242.7
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  236.9
# Nodo:  94 	[ 285 ,  336 ] 	- Travel and Service Time:  247.8
# Nodo iniziale:  33
# Prossimo nodo:  62 Richiesta:  20
# Capacità rimanente:  140
# Tempo corrente:  262.0
# Tempo di attesa:  42.69999999999999
# Nodo:  10 	[ 357 ,  410 ] 	- Travel and Service Time:  386.4
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  406.1
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  385.5
# Nodo:  44 	[ 359 ,  412 ] 	- Travel and Service Time:  370.7
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  372.2
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  383.6
# Nodo:  70 	[ 387 ,  456 ] 	- Travel and Service Time:  397.3
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  357.8
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  394.3
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  384.0
# Nodo:  84 	[ 458 ,  523 ] 	- Travel and Service Time:  382.5
# Nodo:  92 	[ 368 ,  441 ] 	- Travel and Service Time:  404.8
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  404.2
# Nodo iniziale:  62
# Prossimo nodo:  10 Richiesta:  10
# Capacità rimanente:  130
# Tempo corrente:  386.4
# Tempo di attesa:  0
# Nodo:  9 	[ 534 ,  605 ] 	- Travel and Service Time:  481.4
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  499.4
# Nodo:  28 	[ 546 ,  593 ] 	- Travel and Service Time:  492.7
# Nodo:  45 	[ 541 ,  600 ] 	- Travel and Service Time:  512.6999999999999
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  537.4
# Nodo:  61 	[ 531 ,  610 ] 	- Travel and Service Time:  515.4
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  543.8
# Nodo:  77 	[ 574 ,  643 ] 	- Travel and Service Time:  540.5
# Nodo:  84 	[ 458 ,  523 ] 	- Travel and Service Time:  512.3
# Nodo:  85 	[ 555 ,  612 ] 	- Travel and Service Time:  509.9
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  511.9
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  507.79999999999995
# Nodo iniziale:  10
# Prossimo nodo:  28 Richiesta:  20
# Capacità rimanente:  110
# Tempo corrente:  546.0
# Tempo di attesa:  53.30000000000001
# Nodo:  4 	[ 727 ,  782 ] 	- Travel and Service Time:  659.0
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  658.0
# Nodo:  23 	[ 732 ,  777 ] 	- Travel and Service Time:  641.0
# Nodo:  36 	[ 665 ,  716 ] 	- Travel and Service Time:  656.6
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  661.5
# Nodo:  51 	[ 725 ,  786 ] 	- Travel and Service Time:  661.1
# Nodo:  68 	[ 734 ,  777 ] 	- Travel and Service Time:  669.3
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  704.7
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  678.3
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  676.1
# Nodo iniziale:  28
# Prossimo nodo:  51 Richiesta:  10
# Capacità rimanente:  100
# Tempo corrente:  725.0
# Tempo di attesa:  63.89999999999998
# Nodo:  2 	[ 825 ,  870 ] 	- Travel and Service Time:  859.7
# Nodo:  22 	[ 812 ,  883 ] 	- Travel and Service Time:  837.2
# Nodo:  50 	[ 815 ,  880 ] 	- Travel and Service Time:  817.2
# Nodo iniziale:  51
# Prossimo nodo:  22 Richiesta:  20
# Capacità rimanente:  80
# Tempo corrente:  837.2
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  7
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  17 	[ 99 ,  148 ] 	- Travel and Service Time:  33.3
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  32 	[ 31 ,  100 ] 	- Travel and Service Time:  31.6
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  43 	[ 16 ,  80 ] 	- Travel and Service Time:  16.6
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  12.8
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  32 Richiesta:  30
# Capacità rimanente:  170
# Tempo corrente:  31.6
# Tempo di attesa:  0
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  161.29999999999998
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  140.8
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  126.6
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  146.0
# Nodo:  54 	[ 186 ,  257 ] 	- Travel and Service Time:  165.5
# Nodo:  63 	[ 171 ,  218 ] 	- Travel and Service Time:  161.6
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  206.7
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  185.4
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  179.6
# Nodo:  94 	[ 285 ,  336 ] 	- Travel and Service Time:  190.79999999999998
# Nodo iniziale:  32
# Prossimo nodo:  94 Richiesta:  10
# Capacità rimanente:  160
# Tempo corrente:  285.0
# Tempo di attesa:  94.19999999999999
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  420.0
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  436.0
# Nodo:  70 	[ 387 ,  456 ] 	- Travel and Service Time:  435.0
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  428.4
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  433.6
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  403.8
# Nodo:  84 	[ 458 ,  523 ] 	- Travel and Service Time:  399.5
# Nodo:  92 	[ 368 ,  441 ] 	- Travel and Service Time:  378.6
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  378.0
# Nodo iniziale:  94
# Prossimo nodo:  84 Richiesta:  20
# Capacità rimanente:  140
# Tempo corrente:  458.0
# Tempo di attesa:  58.5
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  580.0
# Nodo:  9 	[ 534 ,  605 ] 	- Travel and Service Time:  582.2
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  603.1
# Nodo:  36 	[ 665 ,  716 ] 	- Travel and Service Time:  614.3
# Nodo:  45 	[ 541 ,  600 ] 	- Travel and Service Time:  596.8
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  598.5
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  611.5
# Nodo:  61 	[ 531 ,  610 ] 	- Travel and Service Time:  582.4
# Nodo:  77 	[ 574 ,  643 ] 	- Travel and Service Time:  581.3
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  580.8
# Nodo:  85 	[ 555 ,  612 ] 	- Travel and Service Time:  550.8
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  553.4
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  576.8
# Nodo iniziale:  84
# Prossimo nodo:  77 Richiesta:  10
# Capacità rimanente:  130
# Tempo corrente:  581.3
# Tempo di attesa:  0
# Nodo:  2 	[ 825 ,  870 ] 	- Travel and Service Time:  730.0
# Nodo:  4 	[ 727 ,  782 ] 	- Travel and Service Time:  731.0
# Nodo:  23 	[ 732 ,  777 ] 	- Travel and Service Time:  736.3
# Nodo:  50 	[ 815 ,  880 ] 	- Travel and Service Time:  733.3
# Nodo:  68 	[ 734 ,  777 ] 	- Travel and Service Time:  714.3
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  672.3
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  708.8
# Nodo iniziale:  77
# Prossimo nodo:  4 Richiesta:  10
# Capacità rimanente:  120
# Tempo corrente:  731.0
# Tempo di attesa:  0
# Nodo:  2 	[ 825 ,  870 ] 	- Travel and Service Time:  824.6
# Nodo:  50 	[ 815 ,  880 ] 	- Travel and Service Time:  860.4
# Nodo iniziale:  4
# Prossimo nodo:  50 Richiesta:  10
# Capacità rimanente:  110
# Tempo corrente:  860.4
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  8
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  17 	[ 99 ,  148 ] 	- Travel and Service Time:  33.3
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  43 	[ 16 ,  80 ] 	- Travel and Service Time:  16.6
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  12.8
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  43 Richiesta:  10
# Capacità rimanente:  190
# Tempo corrente:  16.6
# Tempo di attesa:  0
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  138.9
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  138.4
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  125.4
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  129.6
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  109.6
# Nodo:  54 	[ 186 ,  257 ] 	- Travel and Service Time:  133.2
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  128.5
# Nodo:  63 	[ 171 ,  218 ] 	- Travel and Service Time:  124.30000000000001
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  122.4
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  161.6
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  145.2
# Nodo iniziale:  43
# Prossimo nodo:  54 Richiesta:  40
# Capacità rimanente:  150
# Tempo corrente:  186.0
# Tempo di attesa:  52.80000000000001
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  349.4
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  321.7
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  320.7
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  297.2
# Nodo:  44 	[ 359 ,  412 ] 	- Travel and Service Time:  298.4
# Nodo:  70 	[ 387 ,  456 ] 	- Travel and Service Time:  332.6
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  334.6
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  331.8
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  330.1
# Nodo:  92 	[ 368 ,  441 ] 	- Travel and Service Time:  355.1
# Nodo iniziale:  54
# Prossimo nodo:  44 Richiesta:  10
# Capacità rimanente:  140
# Tempo corrente:  359.0
# Tempo di attesa:  60.60000000000002
# Nodo:  9 	[ 534 ,  605 ] 	- Travel and Service Time:  489.4
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  504.9
# Nodo:  45 	[ 541 ,  600 ] 	- Travel and Service Time:  451.0
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  451.8
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  474.2
# Nodo:  61 	[ 531 ,  610 ] 	- Travel and Service Time:  467.0
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  470.0
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  509.0
# Nodo:  85 	[ 555 ,  612 ] 	- Travel and Service Time:  495.9
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  513.1
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  510.7
# Nodo iniziale:  44
# Prossimo nodo:  85 Richiesta:  30
# Capacità rimanente:  110
# Tempo corrente:  555.0
# Tempo di attesa:  59.10000000000002
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  674.4
# Nodo:  23 	[ 732 ,  777 ] 	- Travel and Service Time:  685.3
# Nodo:  36 	[ 665 ,  716 ] 	- Travel and Service Time:  709.8
# Nodo:  68 	[ 734 ,  777 ] 	- Travel and Service Time:  682.8
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  680.5
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  648.0
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  650.4
# Nodo iniziale:  85
# Prossimo nodo:  36 Richiesta:  10
# Capacità rimanente:  100
# Tempo corrente:  709.8
# Tempo di attesa:  0
# Nodo:  2 	[ 825 ,  870 ] 	- Travel and Service Time:  847.0
# Nodo iniziale:  36
# Prossimo nodo:  2 Richiesta:  30
# Capacità rimanente:  70
# Tempo corrente:  847.0
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  9
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  17 	[ 99 ,  148 ] 	- Travel and Service Time:  33.3
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  12.8
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  17 Richiesta:  20
# Capacità rimanente:  180
# Tempo corrente:  99.0
# Tempo di attesa:  65.7
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  212.8
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  194.8
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  213.0
# Nodo:  27 	[ 261 ,  316 ] 	- Travel and Service Time:  212.5
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  229.8
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  231.1
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  237.1
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  275.8
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  246.6
# Nodo iniziale:  17
# Prossimo nodo:  27 Richiesta:  10
# Capacità rimanente:  170
# Tempo corrente:  261.0
# Tempo di attesa:  48.5
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  379.2
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  354.6
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  372.2
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  401.0
# Nodo:  70 	[ 387 ,  456 ] 	- Travel and Service Time:  426.3
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  388.2
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  423.4
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  403.1
# Nodo:  92 	[ 368 ,  441 ] 	- Travel and Service Time:  406.0
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  404.4
# Nodo iniziale:  27
# Prossimo nodo:  92 Richiesta:  20
# Capacità rimanente:  150
# Tempo corrente:  406.0
# Tempo di attesa:  0
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  527.4
# Nodo:  9 	[ 534 ,  605 ] 	- Travel and Service Time:  528.6
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  541.0
# Nodo:  45 	[ 541 ,  600 ] 	- Travel and Service Time:  562.3
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  563.4
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  582.2
# Nodo:  61 	[ 531 ,  610 ] 	- Travel and Service Time:  553.6
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  498.0
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  503.0
# Nodo iniziale:  92
# Prossimo nodo:  61 Richiesta:  10
# Capacità rimanente:  140
# Tempo corrente:  553.6
# Tempo di attesa:  0
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  683.9000000000001
# Nodo:  23 	[ 732 ,  777 ] 	- Travel and Service Time:  676.9
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  665.6
# Nodo:  68 	[ 734 ,  777 ] 	- Travel and Service Time:  648.6
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  680.6
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  677.1
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  674.5
# Nodo iniziale:  61
# Prossimo nodo:  68 Richiesta:  10
# Capacità rimanente:  130
# Tempo corrente:  734.0
# Tempo di attesa:  85.39999999999998
# Nessun nodo raggiungibile
#
#
# Veicolo:  10
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  65 	[ 76 ,  129 ] 	- Travel and Service Time:  12.8
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  65 Richiesta:  10
# Capacità rimanente:  190
# Tempo corrente:  76.0
# Tempo di attesa:  63.2
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  193.2
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  217.9
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  191.9
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  204.3
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  209.3
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  182.4
# Nodo:  63 	[ 171 ,  218 ] 	- Travel and Service Time:  168.0
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  213.3
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  194.3
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  189.4
# Nodo iniziale:  65
# Prossimo nodo:  63 Richiesta:  50
# Capacità rimanente:  140
# Tempo corrente:  171.0
# Tempo di attesa:  3.0
# ...
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  290.2
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  287.6
# Nodo iniziale:  63
# Prossimo nodo:  70 Richiesta:  30
# Capacità rimanente:  110
# Tempo corrente:  387.0
# Tempo di attesa:  79.89999999999998
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  544.4
# Nodo:  9 	[ 534 ,  605 ] 	- Travel and Service Time:  546.6
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  568.4
# Nodo:  45 	[ 541 ,  600 ] 	- Travel and Service Time:  542.0
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  544.0
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  542.0
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  480.0
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  542.2
# Nodo iniziale:  70
# Prossimo nodo:  9 Richiesta:  10
# Capacità rimanente:  100
# Tempo corrente:  546.6
# Tempo di attesa:  0
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  638.8000000000001
# Nodo:  23 	[ 732 ,  777 ] 	- Travel and Service Time:  654.6
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  677.8
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  699.9000000000001
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  665.4
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  664.3000000000001
# Nodo iniziale:  9
# Prossimo nodo:  23 Richiesta:  10
# Capacità rimanente:  90
# Tempo corrente:  732.0
# Tempo di attesa:  77.39999999999998
# Nessun nodo raggiungibile
#
#
# Veicolo:  11
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  81 	[ 47 ,  124 ] 	- Travel and Service Time:  47.4
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  81 Richiesta:  30
# Capacità rimanente:  170
# Tempo corrente:  47.4
# Tempo di attesa:  0
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  192.0
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  220.6
# Nodo:  25 	[ 169 ,  224 ] 	- Travel and Service Time:  199.8
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  212.4
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  217.4
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  187.6
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  140.4
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  165.0
# Nodo iniziale:  81
# Prossimo nodo:  25 Richiesta:  40
# Capacità rimanente:  130
# Tempo corrente:  199.8
# Tempo di attesa:  0
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  318.20000000000005
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  319.5
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  295.20000000000005
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  316.0
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  314.0
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  339.1
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  339.9
# Nodo:  83 	[ 265 ,  338 ] 	- Travel and Service Time:  336.9
# Nodo iniziale:  25
# Prossimo nodo:  83 Richiesta:  10
# Capacità rimanente:  120
# Tempo corrente:  336.90000000000003
# Tempo di attesa:  0
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  485.20000000000005
# Nodo:  45 	[ 541 ,  600 ] 	- Travel and Service Time:  475.80000000000007
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  474.80000000000007
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  489.1
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  458.30000000000007
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  458.90000000000003
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  457.70000000000005
# Nodo iniziale:  83
# Prossimo nodo:  45 Richiesta:  10
# Capacità rimanente:  110
# Tempo corrente:  541.0
# Tempo di attesa:  65.19999999999999
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  671.3
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  633.0
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  688.0
# Nodo:  88 	[ 645 ,  708 ] 	- Travel and Service Time:  677.1
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  674.3
# Nodo iniziale:  45
# Prossimo nodo:  88 Richiesta:  30
# Capacità rimanente:  80
# Tempo corrente:  677.1
# Tempo di attesa:  0
# Nodo:  89 	[ 737 ,  802 ] 	- Travel and Service Time:  769.9
# Nodo iniziale:  88
# Prossimo nodo:  89 Richiesta:  10
# Capacità rimanente:  70
# Tempo corrente:  769.9
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  12
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  5 	[ 15 ,  67 ] 	- Travel and Service Time:  15.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  50.3
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  5 Richiesta:  10
# Capacità rimanente:  190
# Tempo corrente:  15.1
# Tempo di attesa:  0
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  106.1
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  107.3
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  149.0
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  139.3
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  155.1
# Nodo:  78 	[ 109 ,  170 ] 	- Travel and Service Time:  160.0
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  131.1
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  128.5
# Nodo iniziale:  5
# Prossimo nodo:  78 Richiesta:  20
# Capacità rimanente:  170
# Tempo corrente:  160.0
# Tempo di attesa:  0
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  331.5
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  335.8
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  319.6
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  333.0
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  303.2
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  306.6
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  257.0
# Nodo:  82 	[ 369 ,  420 ] 	- Travel and Service Time:  273.9
# Nodo iniziale:  78
# Prossimo nodo:  82 Richiesta:  20
# Capacità rimanente:  150
# Tempo corrente:  369.0
# Tempo di attesa:  95.10000000000002
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  519.9
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  523.0
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  492.3
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  489.2
# Nodo:  93 	[ 475 ,  518 ] 	- Travel and Service Time:  490.6
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  492.5
# Nodo iniziale:  82
# Prossimo nodo:  93 Richiesta:  40
# Capacità rimanente:  110
# Tempo corrente:  490.6
# Tempo di attesa:  0
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  610.3000000000001
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  646.9000000000001
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  639.8
# Nodo:  97 	[ 561 ,  622 ] 	- Travel and Service Time:  585.6
# Nodo iniziale:  93
# Prossimo nodo:  97 Richiesta:  30
# Capacità rimanente:  80
# Tempo corrente:  585.6
# Tempo di attesa:  0
# Nodo:  6 	[ 621 ,  702 ] 	- Travel and Service Time:  701.2
# Nodo iniziale:  97
# Prossimo nodo:  6 Richiesta:  20
# Capacità rimanente:  60
# Tempo corrente:  701.2
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  13
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  20 	[ 10 ,  73 ] 	- Travel and Service Time:  10.0
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  19.3
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  20 Richiesta:  10
# Capacità rimanente:  190
# Tempo corrente:  10.0
# Tempo di attesa:  0.0
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  120.0
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  118.9
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  125.0
# Nodo:  42 	[ 68 ,  149 ] 	- Travel and Service Time:  118.2
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  137.0
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  136.3
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  142.4
# Nodo iniziale:  20
# Prossimo nodo:  42 Richiesta:  20
# Capacità rimanente:  170
# Tempo corrente:  118.2
# Tempo di attesa:  0
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  259.5
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  231.4
# Nodo:  35 	[ 283 ,  344 ] 	- Travel and Service Time:  236.4
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  211.0
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  270.3
# Nodo iniziale:  42
# Prossimo nodo:  35 Richiesta:  10
# Capacità rimanente:  160
# Tempo corrente:  283.0
# Tempo di attesa:  46.60000000000002
# Nodo:  15 	[ 384 ,  429 ] 	- Travel and Service Time:  420.4
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  394.2
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  398.2
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  419.1
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  421.3
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  460.1
# Nodo iniziale:  35
# Prossimo nodo:  15 Richiesta:  40
# Capacità rimanente:  120
# Tempo corrente:  420.4
# Tempo di attesa:  0
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  515.8
# Nodo:  48 	[ 632 ,  693 ] 	- Travel and Service Time:  561.0
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  586.9
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  594.0
# Nodo iniziale:  15
# Prossimo nodo:  48 Richiesta:  10
# Capacità rimanente:  110
# Tempo corrente:  632.0
# Tempo di attesa:  71.0
# Nessun nodo raggiungibile
#
#
# Veicolo:  14
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  13 	[ 30 ,  92 ] 	- Travel and Service Time:  30.8
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  13 Richiesta:  30
# Capacità rimanente:  170
# Tempo corrente:  30.8
# Tempo di attesa:  0
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  142.70000000000002
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  140.9
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  162.60000000000002
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  167.60000000000002
# Nodo:  71 	[ 293 ,  360 ] 	- Travel and Service Time:  204.0
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  169.10000000000002
# Nodo iniziale:  13
# Prossimo nodo:  71 Richiesta:  20
# Capacità rimanente:  150
# Tempo corrente:  293.0
# Tempo di attesa:  89.0
# Nodo:  14 	[ 567 ,  620 ] 	- Travel and Service Time:  471.5
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  448.1
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  425.3
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  388.8
# Nodo iniziale:  71
# Prossimo nodo:  14 Richiesta:  10
# Capacità rimanente:  140
# Tempo corrente:  567.0
# Tempo di attesa:  95.5
# Nessun nodo raggiungibile
#
#
# Veicolo:  15
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  90 	[ 20 ,  84 ] 	- Travel and Service Time:  20.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  90 Richiesta:  10
# Capacità rimanente:  190
# Tempo corrente:  20.6
# Tempo di attesa:  0
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  131.7
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  133.4
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  164.5
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  154.5
# Nodo:  86 	[ 173 ,  238 ] 	- Travel and Service Time:  116.6
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  135.6
# Nodo iniziale:  90
# Prossimo nodo:  86 Richiesta:  10
# Capacità rimanente:  180
# Tempo corrente:  173.0
# Tempo di attesa:  56.400000000000006
# Nodo:  19 	[ 278 ,  345 ] 	- Travel and Service Time:  319.8
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  309.3
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  302.8
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  319.4
# Nodo iniziale:  86
# Prossimo nodo:  19 Richiesta:  10
# Capacità rimanente:  170
# Tempo corrente:  319.8
# Tempo di attesa:  0
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  460.1
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  487.4
# Nodo:  72 	[ 450 ,  505 ] 	- Travel and Service Time:  472.6
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  501.6
# Nodo iniziale:  19
# Prossimo nodo:  72 Richiesta:  10
# Capacità rimanente:  160
# Tempo corrente:  472.6
# Tempo di attesa:  0
# Nodo:  60 	[ 562 ,  629 ] 	- Travel and Service Time:  593.4
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  596.6
# Nodo iniziale:  72
# Prossimo nodo:  60 Richiesta:  20
# Capacità rimanente:  140
# Tempo corrente:  593.4
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  16
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo:  96 	[ 95 ,  156 ] 	- Travel and Service Time:  36.1
# Nodo iniziale:  0
# Prossimo nodo:  96 Richiesta:  10
# Capacità rimanente:  190
# Tempo corrente:  95.0
# Tempo di attesa:  58.9
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  209.4
# Nodo:  40 	[ 264 ,  321 ] 	- Travel and Service Time:  240.9
# Nodo iniziale:  96
# Prossimo nodo:  40 Richiesta:  10
# Capacità rimanente:  180
# Tempo corrente:  264.0
# Tempo di attesa:  23.099999999999994
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  379.0
# Nodo:  46 	[ 448 ,  509 ] 	- Travel and Service Time:  359.4
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  379.5
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  411.0
# Nodo iniziale:  40
# Prossimo nodo:  46 Richiesta:  30
# Capacità rimanente:  150
# Tempo corrente:  448.0
# Tempo di attesa:  88.60000000000002
# Nodo:  79 	[ 668 ,  731 ] 	- Travel and Service Time:  595.0
# Nodo iniziale:  46
# Prossimo nodo:  79 Richiesta:  10
# Capacità rimanente:  140
# Tempo corrente:  668.0
# Tempo di attesa:  73.0
# Nessun nodo raggiungibile
#
#
# Veicolo:  17
# Nodo:  3 	[ 65 ,  146 ] 	- Travel and Service Time:  16.1
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo iniziale:  0
# Prossimo nodo:  3 Richiesta:  10
# Capacità rimanente:  190
# Tempo corrente:  65.0
# Tempo di attesa:  48.9
# Nodo:  7 	[ 170 ,  225 ] 	- Travel and Service Time:  157.0
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  199.6
# Nodo iniziale:  3
# Prossimo nodo:  7 Richiesta:  20
# Capacità rimanente:  170
# Tempo corrente:  170.0
# Tempo di attesa:  13.0
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  285.6
# Nodo:  56 	[ 385 ,  436 ] 	- Travel and Service Time:  321.0
# Nodo iniziale:  7
# Prossimo nodo:  56 Richiesta:  30
# Capacità rimanente:  140
# Tempo corrente:  385.0
# Tempo di attesa:  64.0
# Nodo:  73 	[ 478 ,  551 ] 	- Travel and Service Time:  532.7
# Nodo iniziale:  56
# Prossimo nodo:  73 Richiesta:  10
# Capacità rimanente:  130
# Tempo corrente:  532.7
# Tempo di attesa:  0
# Nessun nodo raggiungibile
#
#
# Veicolo:  18
# Nodo:  55 	[ 95 ,  158 ] 	- Travel and Service Time:  35.1
# Nodo iniziale:  0
# Prossimo nodo:  55 Richiesta:  10
# Capacità rimanente:  190
# Tempo corrente:  95.0
# Tempo di attesa:  59.9
# Nodo:  31 	[ 200 ,  237 ] 	- Travel and Service Time:  222.7
# Nodo iniziale:  55
# Prossimo nodo:  31 Richiesta:  20
# Capacità rimanente:  170
# Tempo corrente:  222.7
# Tempo di attesa:  0
# Nodo:  29 	[ 358 ,  405 ] 	- Travel and Service Time:  330.7
# Nodo iniziale:  31
# Prossimo nodo:  29 Richiesta:  10
# Capacità rimanente:  160
# Tempo corrente:  358.0
# Tempo di attesa:  27.30000000000001

# %%
print("Nodi non esplorati: ", len(list_nodes))
print("Veicoli utilizzati: ",k)
for u in solution:
    print(u.number)
times
# Out:
# Nodi non esplorati:  0
# Veicoli utilizzati:  18
# 0
# 87
# 76
# 38
# 59
# 66
# 75
# 47
# 0
# 24
# 18
# 37
# 30
# 12
# 99
# 21
# 49
# 0
# 67
# 41
# 74
# 11
# 26
# 91
# 1
# 0
# 57
# 95
# 8
# 16
# 39
# 80
# 52
# 0
# 98
# 53
# 58
# 64
# 34
# 69
# 0
# 33
# 62
# 10
# 28
# 51
# 22
# 0
# 32
# 94
# 84
# 77
# 4
# 50
# 0
# 43
# 54
# 44
# 85
# 36
# 2
# 0
# 17
# 27
# 92
# 61
# 68
# 0
# 65
# 63
# 70
# 9
# 23
# 0
# 81
# 25
# 83
# 45
# 88
# 89
# 0
# 5
# 78
# 82
# 93
# 97
# 6
# 0
# 20
# 42
# 35
# 15
# 48
# 0
# 13
# 71
# 14
# 0
# 90
# 86
# 19
# 72
# 60
# 0
# 96
# 40
# 46
# 79
# 0
# 3
# 7
# 56
# 73
# 0
# 55
# 31
# 29
# [85.0,
#  207.0,
#  479.0,
#  651.0,
#  826.0,
#  997.0,
#  1120.5,
#  65.0,
#  181.9,
#  383.0,
#  496.4,
#  652.0,
#  772.4,
#  914.0,
#  1021.1,
#  12.2,
#  166.0,
#  353.0,
#  481.5,
#  622.0,
#  836.0,
#  943.0,
#  35.0,
#  196.0,
#  312.8,
#  475.0,
#  609.7,
#  787.0,
#  937.8,
#  30.8,
#  286.0,
#  471.0,
#  632.0,
#  764.7,
#  916.0,
#  87.0,
#  262.0,
#  386.4,
#  546.0,
#  725.0,
#  837.2,
#  31.6,
#  285.0,
#  458.0,
#  581.3,
#  731.0,
#  860.4,
#  16.6,
#  186.0,
#  359.0,
#  555.0,
#  709.8,
#  847.0,
#  99.0,
#  261.0,
#  406.0,
#  553.6,
#  734.0,
#  76.0,
#  171.0,
#  387.0,
#  546.6,
#  732.0,
#  47.4,
#  199.8,
#  336.90000000000003,
#  541.0,
#  677.1,
#  769.9,
#  15.1,
#  160.0,
#  369.0,
#  490.6,
#  585.6,
#  701.2,
#  10.0,
#  118.2,
#  283.0,
#  420.4,
#  632.0,
#  30.8,
#  293.0,
#  567.0,
#  20.6,
#  173.0,
#  319.8,
#  472.6,
#  593.4,
#  95.0,
#  264.0,
#  448.0,
#  668.0,
#  65.0,
#  170.0,
#  385.0,
#  532.7,
#  95.0,
#  222.7,
#  358.0]
